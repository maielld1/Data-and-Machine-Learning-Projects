# %%
import nltk
import pandas as pd

# %%
comments = pd.read_excel('Notebook_Data.xlsx')
comments.head()
# Out:
#                        TopicName  \
# 0    What is going well and why?
# 1  What can be improved and how?
# 2                          Other
# 3    What is going well and why?
# 4  What can be improved and how?
#
#                                              Comment
# 0  The atmosphere in Wayne is more relaxed and it...
# 1  You already know who I am based on the first f...
# 2  I've been very loyal to this company and have ...
# 3  It is good that we don't have separate resourc...
# 4  Working on 2 releases and production support a...

# %% [markdown]
# # Word and Sentence Tokenizer

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

comments['Sentence Tokens'] = comments['Comment'].apply(sent_tokenize)
comments['Word Tokens'] = comments['Comment'].apply(word_tokenize)
#print(sent_tokenize(comments['Comment'][0]))
comments['Sentence Tokens'][0]
# Out:
# ['The atmosphere in Wayne is more relaxed and it seems people are happier.',
#  'Some leadership changes appear to have started this trend.']

# %%
comments['Word Tokens'][0]
# Out:
# ['The',
#  'atmosphere',
#  'in',
#  'Wayne',
#  'is',
#  'more',
#  'relaxed',
#  'and',
#  'it',
#  'seems',
#  'people',
#  'are',
#  'happier',
#  '.',
#  'Some',
#  'leadership',
#  'changes',
#  'appear',
#  'to',
#  'have',
#  'started',
#  'this',
#  'trend',
#  '.']

# %%
comments.head()
# Out:
#                        TopicName  \
# 0    What is going well and why?
# 1  What can be improved and how?
# 2                          Other
# 3    What is going well and why?
# 4  What can be improved and how?
#
#                                              Comment  \
# 0  The atmosphere in Wayne is more relaxed and it...
# 1  You already know who I am based on the first f...
# 2  I've been very loyal to this company and have ...
# 3  It is good that we don't have separate resourc...
# 4  Working on 2 releases and production support a...
#
#                                      Sentence Tokens  \
# 0  [The atmosphere in Wayne is more relaxed and i...
# 1  [You already know who I am based on the first ...
# 2  [I've been very loyal to this company and have...
# 3  [It is good that we don't have separate resour...
# 4  [Working on 2 releases and production support ...
#
#                                          Word Tokens
# 0  [The, atmosphere, in, Wayne, is, more, relaxed...
# 1  [You, already, know, who, I, am, based, on, th...
# 2  [I, 've, been, very, loyal, to, this, company,...
# 3  [It, is, good, that, we, do, n't, have, separa...
# 4  [Working, on, 2, releases, and, production, su...

# %% [markdown]
# # Stop Words

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
def filter_stop(word_tokens):
    filtered_words = []
    for w in word_tokens:
        if w not in stop_words:
            filtered_words.append(w)
    return filtered_words
#filtered_sentence = [w for w in word_tokens if not w in stop_words]
comments['Filtered Words'] = comments['Word Tokens'].apply(filter_stop)
comments['Filtered Words'][0]
# Out:
# ['The',
#  'atmosphere',
#  'Wayne',
#  'relaxed',
#  'seems',
#  'people',
#  'happier',
#  '.',
#  'Some',
#  'leadership',
#  'changes',
#  'appear',
#  'started',
#  'trend',
#  '.']

# %%
comments.head()
# Out:
#                        TopicName  \
# 0    What is going well and why?
# 1  What can be improved and how?
# 2                          Other
# 3    What is going well and why?
# 4  What can be improved and how?
#
#                                              Comment  \
# 0  The atmosphere in Wayne is more relaxed and it...
# 1  You already know who I am based on the first f...
# 2  I've been very loyal to this company and have ...
# 3  It is good that we don't have separate resourc...
# 4  Working on 2 releases and production support a...
#
#                                      Sentence Tokens  \
# 0  [The atmosphere in Wayne is more relaxed and i...
# 1  [You already know who I am based on the first ...
# 2  [I've been very loyal to this company and have...
# 3  [It is good that we don't have separate resour...
# 4  [Working on 2 releases and production support ...
#
#                                          Word Tokens  \
# 0  [The, atmosphere, in, Wayne, is, more, relaxed...
# 1  [You, already, know, who, I, am, based, on, th...
# 2  [I, 've, been, very, loyal, to, this, company,...
# 3  [It, is, good, that, we, do, n't, have, separa...
# 4  [Working, on, 2, releases, and, production, su...
#
#                                       Filtered Words
# 0  [The, atmosphere, Wayne, relaxed, seems, peopl...
# 1  [You, already, know, I, based, first, question...
# 2  [I, 've, loyal, company, worked, hard, ., For,...
# 3  [It, good, n't, separate, resources, releases,...
# 4  [Working, 2, releases, production, support, ti...

# %% [markdown]
# # Parts of Speech

# %%
pos = []
for comment in comments['Filtered Words']:
     pos.append(nltk.pos_tag(comment))

comments['POS'] = pos
comments['POS'][0]
# Out:
# [('The', 'DT'),
#  ('atmosphere', 'JJ'),
#  ('Wayne', 'NNP'),
#  ('relaxed', 'VBD'),
#  ('seems', 'VBZ'),
#  ('people', 'NNS'),
#  ('happier', 'RBR'),
#  ('.', '.'),
#  ('Some', 'DT'),
#  ('leadership', 'NN'),
#  ('changes', 'NNS'),
#  ('appear', 'VBP'),
#  ('started', 'VBN'),
#  ('trend', 'NN'),
#  ('.', '.')]

# %%
comments.head()
# Out:
#                        TopicName  \
# 0    What is going well and why?
# 1  What can be improved and how?
# 2                          Other
# 3    What is going well and why?
# 4  What can be improved and how?
#
#                                              Comment  \
# 0  The atmosphere in Wayne is more relaxed and it...
# 1  You already know who I am based on the first f...
# 2  I've been very loyal to this company and have ...
# 3  It is good that we don't have separate resourc...
# 4  Working on 2 releases and production support a...
#
#                                      Sentence Tokens  \
# 0  [The atmosphere in Wayne is more relaxed and i...
# 1  [You already know who I am based on the first ...
# 2  [I've been very loyal to this company and have...
# 3  [It is good that we don't have separate resour...
# 4  [Working on 2 releases and production support ...
#
#                                          Word Tokens  \
# 0  [The, atmosphere, in, Wayne, is, more, relaxed...
# 1  [You, already, know, who, I, am, based, on, th...
# 2  [I, 've, been, very, loyal, to, this, company,...
# 3  [It, is, good, that, we, do, n't, have, separa...
# 4  [Working, on, 2, releases, and, production, su...
#
#                                       Filtered Words  \
# 0  [The, atmosphere, Wayne, relaxed, seems, peopl...
# 1  [You, already, know, I, based, first, question...
# 2  [I, 've, loyal, company, worked, hard, ., For,...
# 3  [It, good, n't, separate, resources, releases,...
# 4  [Working, 2, releases, production, support, ti...
#
#                                                  POS
# 0  [(The, DT), (atmosphere, JJ), (Wayne, NNP), (r...
# 1  [(You, PRP), (already, RB), (know, VBP), (I, P...
# 2  [(I, PRP), ('ve, VBP), (loyal, JJ), (company, ...
# 3  [(It, PRP), (good, JJ), (n't, RB), (separate, ...
# 4  [(Working, VBG), (2, CD), (releases, NNS), (pr...

# %% [markdown]
# # Sentiment Analysis using Afinn Word List

# %%
from afinn import Afinn
afinn = Afinn()
print(afinn.score(comments['Comment'][0]))
# Out:
# 3.0

# %%
print(afinn.score(comments['Comment'][5]))
# Out:
# 2.0

# %%
afinn_sent = [afinn.score(comment) for comment in comments['Comment']]
comments['AFINN Score'] = afinn_sent
comments[['Comment', 'AFINN Score']]
# Out:
#                                               Comment  AFINN Score
# 0   The atmosphere in Wayne is more relaxed and it...          3.0
# 1   You already know who I am based on the first f...          3.0
# 2   I've been very loyal to this company and have ...          2.0
# 3   It is good that we don't have separate resourc...          5.0
# 4   Working on 2 releases and production support a...          4.0
# 5   3 day telework will definitely help manage wor...          2.0
# 6   Project is going well  most people are committ...          1.0
# 7   Need to improve work life balance and minimize...          3.0
# 8   UPS is changing to accommodate the needs for u...          9.0
# 9   The QPR process could be improved better   bei...          8.0
# 10  Put more standard and training to encourage  t...         11.0
# 11  What's going well is the atmosphere  people  a...          2.0
# 12  Right now (I'm also a millennial)  I am notici...          6.0
# 13  Right now there are many people who are travel...          7.0
# 14  UPS recent changes in the area of a more relax...          7.0
# 15  Inclusion of healthy living tips  better eatin...          4.0
# 16  Coming from startup companies  UPS provides me...          2.0
# 17   We need more UPS business and processes training          0.0
# 18  We also would love to learn more about UPS tec...          3.0
# 19  Our team is a group that gets along well and s...          7.0
# 20  Our team is a incubator for new talent  so peo...          3.0
# 21  Teamwork is going well because of good communi...          3.0
# 22  some of the processing can be improved by impl...          2.0
# 23  We have some applications using very old and o...          0.0
# 24  Reaching 20 years of service   and I suppose m...         17.0
# 25  We require our leaders to be good managers and...          9.0
# 26  Projects get delivered with fairly well tested...          0.0
# 27  Life work balance is always in need of attenti...          1.0

# %%
all_words = []
for comment in comments['Filtered Words']:
     for word in comment:
            all_words.append(word)

all_words = nltk.FreqDist(all_words)
all_words.most_common(25)
# Out:
# [('.', 53),
#  ('I', 11),
#  ('work', 11),
#  ('We', 9),
#  ('well', 9),
#  ('new', 8),
#  ('many', 8),
#  ('UPS', 8),
#  ('team', 8),
#  ('people', 7),
#  ("n't", 7),
#  ('always', 6),
#  ('good', 5),
#  ('time', 5),
#  ('company', 4),
#  ('get', 4),
#  ('opportunities', 4),
#  ('way', 4),
#  ('going', 4),
#  ('within', 4),
#  ("'s", 4),
#  ('technologies', 4),
#  ('The', 3),
#  ('leadership', 3),
#  ('leaving', 3)]

# %% [markdown]
# # Applying Stemming and Investigating AFINN more

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()
stem_scores = []
for comment in comments['Word Tokens']:
    total_score = 0
    for word in comment:
        word = ps.stem(word)
    sentence = ' '.join(comment)
    score = afinn.score(sentence)
    total_score+=score
    stem_scores.append(total_score)
    
comments['AFINN scores by stemming'] = stem_scores
comments['AFINN scores by stemming']
# Out:
# 0      3.0
# 1      3.0
# 2      2.0
# 3      5.0
# 4      4.0
# 5      2.0
# 6      1.0
# 7      3.0
# 8      9.0
# 9      8.0
# 10    11.0
# 11     2.0
# 12     6.0
# 13     7.0
# 14     7.0
# 15     4.0
# 16     2.0
# 17     0.0
# 18     3.0
# 19     7.0
# 20     3.0
# 21     3.0
# 22     2.0
# 23     0.0
# 24    17.0
# 25     9.0
# 26     0.0
# 27     1.0
# Name: AFINN scores by stemming, dtype: float64

# %%
comments
# Out:
#                          TopicName  \
# 0      What is going well and why?
# 1    What can be improved and how?
# 2                            Other
# 3      What is going well and why?
# 4    What can be improved and how?
# 5    Work/Life Balance/Environment
# 6      What is going well and why?
# 7    What can be improved and how?
# 8      What is going well and why?
# 9    What can be improved and how?
# 10  Trust/Fairness/Professionalism
# 11     What is going well and why?
# 12   What can be improved and how?
# 13           Compensation/Benefits
# 14     What is going well and why?
# 15     Health, Safety and Wellness
# 16     What is going well and why?
# 17   What can be improved and how?
# 18                      Innovation
# 19     What is going well and why?
# 20   What can be improved and how?
# 21     What is going well and why?
# 22   What can be improved and how?
# 23                      Innovation
# 24     What is going well and why?
# 25   What can be improved and how?
# 26     What is going well and why?
# 27   What can be improved and how?
#
#                                               Comment  \
# 0   The atmosphere in Wayne is more relaxed and it...
# 1   You already know who I am based on the first f...
# 2   I've been very loyal to this company and have ...
# 3   It is good that we don't have separate resourc...
# 4   Working on 2 releases and production support a...
# 5   3 day telework will definitely help manage wor...
# 6   Project is going well  most people are committ...
# 7   Need to improve work life balance and minimize...
# 8   UPS is changing to accommodate the needs for u...
# 9   The QPR process could be improved better   bei...
# 10  Put more standard and training to encourage  t...
# 11  What's going well is the atmosphere  people  a...
# 12  Right now (I'm also a millennial)  I am notici...
# 13  Right now there are many people who are travel...
# 14  UPS recent changes in the area of a more relax...
# 15  Inclusion of healthy living tips  better eatin...
# 16  Coming from startup companies  UPS provides me...
# 17   We need more UPS business and processes training
# 18  We also would love to learn more about UPS tec...
# 19  Our team is a group that gets along well and s...
# 20  Our team is a incubator for new talent  so peo...
# 21  Teamwork is going well because of good communi...
# 22  some of the processing can be improved by impl...
# 23  We have some applications using very old and o...
# 24  Reaching 20 years of service   and I suppose m...
# 25  We require our leaders to be good managers and...
# 26  Projects get delivered with fairly well tested...
# 27  Life work balance is always in need of attenti...
#
#                                       Sentence Tokens  \
# 0   [The atmosphere in Wayne is more relaxed and i...
# 1   [You already know who I am based on the first ...
# 2   [I've been very loyal to this company and have...
# 3   [It is good that we don't have separate resour...
# 4   [Working on 2 releases and production support ...
# 5   [3 day telework will definitely help manage wo...
# 6   [Project is going well  most people are commit...
# 7   [Need to improve work life balance and minimiz...
# 8   [UPS is changing to accommodate the needs for ...
# 9   [The QPR process could be improved better   be...
# 10  [Put more standard and training to encourage  ...
# 11  [What's going well is the atmosphere  people  ...
# 12  [Right now (I'm also a millennial)  I am notic...
# 13  [Right now there are many people who are trave...
# 14  [UPS recent changes in the area of a more rela...
# 15  [Inclusion of healthy living tips  better eati...
# 16  [Coming from startup companies  UPS provides m...
# 17  [We need more UPS business and processes train...
# 18  [We also would love to learn more about UPS te...
# 19  [Our team is a group that gets along well and ...
# 20  [Our team is a incubator for new talent  so pe...
# 21  [Teamwork is going well because of good commun...
# 22  [some of the processing can be improved by imp...
# 23  [We have some applications using very old and ...
# 24  [Reaching 20 years of service   and I suppose ...
# 25  [We require our leaders to be good managers an...
# 26  [Projects get delivered with fairly well teste...
# 27  [Life work balance is always in need of attent...
#
#                                           Word Tokens  \
# 0   [The, atmosphere, in, Wayne, is, more, relaxed...
# 1   [You, already, know, who, I, am, based, on, th...
# 2   [I, 've, been, very, loyal, to, this, company,...
# 3   [It, is, good, that, we, do, n't, have, separa...
# 4   [Working, on, 2, releases, and, production, su...
# 5   [3, day, telework, will, definitely, help, man...
# 6   [Project, is, going, well, most, people, are, ...
# 7   [Need, to, improve, work, life, balance, and, ...
# 8   [UPS, is, changing, to, accommodate, the, need...
# 9   [The, QPR, process, could, be, improved, bette...
# 10  [Put, more, standard, and, training, to, encou...
# 11  [What, 's, going, well, is, the, atmosphere, p...
# 12  [Right, now, (, I, 'm, also, a, millennial, ),...
# 13  [Right, now, there, are, many, people, who, ar...
# 14  [UPS, recent, changes, in, the, area, of, a, m...
# 15  [Inclusion, of, healthy, living, tips, better,...
# 16  [Coming, from, startup, companies, UPS, provid...
# 17  [We, need, more, UPS, business, and, processes...
# 18  [We, also, would, love, to, learn, more, about...
# 19  [Our, team, is, a, group, that, gets, along, w...
# 20  [Our, team, is, a, incubator, for, new, talent...
# 21  [Teamwork, is, going, well, because, of, good,...
# 22  [some, of, the, processing, can, be, improved,...
# 23  [We, have, some, applications, using, very, ol...
# 24  [Reaching, 20, years, of, service, and, I, sup...
# 25  [We, require, our, leaders, to, be, good, mana...
# 26  [Projects, get, delivered, with, fairly, well,...
# 27  [Life, work, balance, is, always, in, need, of...
#
#                                        Filtered Words  \
# 0   [The, atmosphere, Wayne, relaxed, seems, peopl...
# 1   [You, already, know, I, based, first, question...
# 2   [I, 've, loyal, company, worked, hard, ., For,...
# 3   [It, good, n't, separate, resources, releases,...
# 4   [Working, 2, releases, production, support, ti...
# 5   [3, day, telework, definitely, help, manage, w...
# 6   [Project, going, well, people, committed, work...
# 7   [Need, improve, work, life, balance, minimize,...
# 8   [UPS, changing, accommodate, needs, us, great,...
# 9   [The, QPR, process, could, improved, better, n...
# 10  [Put, standard, training, encourage, employee,...
# 11  [What, 's, going, well, atmosphere, people, re...
# 12  [Right, (, I, 'm, also, millennial, ), I, noti...
# 13  [Right, many, people, traveling, distance, wor...
# 14  [UPS, recent, changes, area, relaxed, dress, c...
# 15  [Inclusion, healthy, living, tips, better, eat...
# 16  [Coming, startup, companies, UPS, provides, st...
# 17     [We, need, UPS, business, processes, training]
# 18  [We, also, would, love, learn, UPS, technologi...
# 19  [Our, team, group, gets, along, well, shares, ...
# 20  [Our, team, incubator, new, talent, people, n'...
# 21  [Teamwork, going, well, good, communication, a...
# 22  [processing, improved, implementing, new, late...
# 23  [We, applications, using, old, outdated, techn...
# 24  [Reaching, 20, years, service, I, suppose, mid...
# 25  [We, require, leaders, good, managers, also, r...
# 26  [Projects, get, delivered, fairly, well, teste...
# 27  [Life, work, balance, always, need, attention,...
#
#                                                   POS  AFINN Score  \
# 0   [(The, DT), (atmosphere, JJ), (Wayne, NNP), (r...          3.0
# 1   [(You, PRP), (already, RB), (know, VBP), (I, P...          3.0
# 2   [(I, PRP), ('ve, VBP), (loyal, JJ), (company, ...          2.0
# 3   [(It, PRP), (good, JJ), (n't, RB), (separate, ...          5.0
# 4   [(Working, VBG), (2, CD), (releases, NNS), (pr...          4.0
# 5   [(3, CD), (day, NN), (telework, NN), (definite...          2.0
# 6   [(Project, NN), (going, VBG), (well, RB), (peo...          1.0
# 7   [(Need, NNP), (improve, VB), (work, NN), (life...          3.0
# 8   [(UPS, NNP), (changing, VBG), (accommodate, NN...          9.0
# 9   [(The, DT), (QPR, NNP), (process, NN), (could,...          8.0
# 10  [(Put, VB), (standard, JJ), (training, NN), (e...         11.0
# 11  [(What, WP), ('s, VBZ), (going, VBG), (well, R...          2.0
# 12  [(Right, NNP), ((, (), (I, PRP), ('m, VBP), (a...          6.0
# 13  [(Right, RB), (many, JJ), (people, NNS), (trav...          7.0
# 14  [(UPS, NNP), (recent, JJ), (changes, NNS), (ar...          7.0
# 15  [(Inclusion, NNP), (healthy, JJ), (living, NN)...          4.0
# 16  [(Coming, VBG), (startup, NN), (companies, NNS...          2.0
# 17  [(We, PRP), (need, VBP), (UPS, JJ), (business,...          0.0
# 18  [(We, PRP), (also, RB), (would, MD), (love, VB...          3.0
# 19  [(Our, PRP$), (team, NN), (group, NN), (gets, ...          7.0
# 20  [(Our, PRP$), (team, NN), (incubator, NN), (ne...          3.0
# 21  [(Teamwork, NN), (going, VBG), (well, RB), (go...          3.0
# 22  [(processing, VBG), (improved, VBN), (implemen...          2.0
# 23  [(We, PRP), (applications, NNS), (using, VBG),...          0.0
# 24  [(Reaching, VBG), (20, CD), (years, NNS), (ser...         17.0
# 25  [(We, PRP), (require, VBP), (leaders, NNS), (g...          9.0
# 26  [(Projects, NNS), (get, VBP), (delivered, VBN)...          0.0
# 27  [(Life, NNP), (work, NN), (balance, NN), (alwa...          1.0
#
#     AFINN scores by stemming
# 0                        3.0
# 1                        3.0
# 2                        2.0
# 3                        5.0
# 4                        4.0
# 5                        2.0
# 6                        1.0
# 7                        3.0
# 8                        9.0
# 9                        8.0
# 10                      11.0
# 11                       2.0
# 12                       6.0
# 13                       7.0
# 14                       7.0
# 15                       4.0
# 16                       2.0
# 17                       0.0
# 18                       3.0
# 19                       7.0
# 20                       3.0
# 21                       3.0
# 22                       2.0
# 23                       0.0
# 24                      17.0
# 25                       9.0
# 26                       0.0
# 27                       1.0

# %% [markdown]
# No difference if you stem the words or not.

# %% [markdown]
# ## More info about AFINN
#
# https://github.com/fnielsen/afinn
#
# Looks like they can look for emoticons!!
#
# def __init__(self, language="en", emoticons=False, word_boundary=True):

# %%
afinn.score('This company is great!')
# Out:
# 3.0

# %%
afinn = Afinn(emoticons=True)
afinn.score('This company is great! :)))))))')
# Out:
# 7.0

# %%
afinn = Afinn()
afinn.score('I hate this company!')
# Out:
# -3.0

# %%
afinn = Afinn(emoticons=True)
afinn.score('I hate this company! :((((((')
# Out:
# -6.0

# %%
afinn = Afinn()
afinn.score('I hate this company! :((((((')
# Out:
# -3.0

# %% [markdown]
# # LDA Models (Topic Modelling) Latent Dirichlet Allocation
#
# resources:
# 1.  https://github.com/bmabey/pyLDAvis interesting tool for visualizing to explore
#
# https://nbviewer.jupyter.org/github/bmabey/pyLDAvis/blob/master/notebooks/Movie%20Reviews%2C%20AP%20News%2C%20and%20Jeopardy.ipynb
#
# 2.  http://www.analyticsvidhya.com/blog/2016/08/beginners-guide-to-topic-modeling-in-python/
#
# 3.  http://chdoig.github.io/pygotham-topic-modeling/#/1/3
#
# 4.  https://radimrehurek.com/gensim/  library
#
# 5.  http://pythonhosted.org//lda/   library
#
# 6.  https://github.com/tdhopper/notes-on-dirichlet-processes notebooks

# %%
import gensim
# Out:
# C:\Users\yanke_000\Anaconda3\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
